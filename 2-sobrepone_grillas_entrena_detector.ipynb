# %%
import os, glob, random, uuid
import math
import cv2
import matplotlib.pyplot as plt
import numpy as np
import imutils
from pathlib import Path
import torch
from torchvision import models, transforms
from torch.utils.data import DataLoader
from PIL import Image

# %% [markdown]
# **Este script se usa para separar las bubbles que tienen cruz de las que no tienen cruz. Se usará para entrenar la red neuronal (en el siguiente script)**
#
# INPUT: 4 crops de cada examen (student_name, grida, gridb, gridc)
#
# OUTPUT: dos carpetas con bubbles con cruz o sin cruz

# %% [markdown]
# ### Envio de TARGET_SAMPLES recuadros a la carpeta para posterior clasificacion

# %%
# configuro rutas
CROPS_DIR     = "cropped_columns"
CROSSED_DIR   = "cropped_columns/0-CROSSED"     # no usado en este script
UNCROSSED_DIR = "cropped_columns/1-UNCROSSED"

os.makedirs(CROSSED_DIR, exist_ok=True)
os.makedirs(UNCROSSED_DIR, exist_ok=True)

#  especificaciones de grilla (n_filas, n_columnas)
grid_specs = {
    "col1": (14, 4),
    "col2": (14, 4),
    "cpl3": (12, 4),
}

# recolectar todas las grillas válidas
candidates = []
for folder in os.listdir(CROPS_DIR):
    fp = os.path.join(CROPS_DIR, folder)
    if not os.path.isdir(fp):
        continue
    for fname in os.listdir(fp):
        name_no_ext, ext = os.path.splitext(fname)
        if name_no_ext in grid_specs:
            candidates.append((fp, fname, grid_specs[name_no_ext]))

if not candidates:
    raise RuntimeError("No grid images found in your crops directory!")

# construir universo de celdas únicas (sin cargar imágenes todavía)
universe = []  # (folder_path, fname, n_rows, n_cols, i, j)
for folder_path, fname, (n_rows, n_cols) in candidates:
    for i in range(n_rows):
        for j in range(n_cols):
            universe.append((folder_path, fname, n_rows, n_cols, i, j))

# muestreo sin reemplazo
TARGET_SAMPLES = 4000
total_unique = len(universe)
if total_unique == 0:
    raise RuntimeError("No hay celdas disponibles en las grillas.")

if total_unique < TARGET_SAMPLES:
    print(f"[AVISO] Solo hay {total_unique} celdas únicas. Se guardarán todas.")
    TARGET_SAMPLES = total_unique

random.seed(18)  # reproducible
selection = random.sample(universe, k=TARGET_SAMPLES)

# guardar las celdas en UNCROSSED automáticamente
saved = 0
for (folder_path, fname, n_rows, n_cols, i, j) in selection:
    img_path = os.path.join(folder_path, fname)
    img = cv2.imread(img_path)
    if img is None:
        print(f"[WARN] No pude leer {img_path}, salto.")
        continue
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    h, w = img.shape[:2]
    cell_h, cell_w = h / n_rows, w / n_cols

    y1, y2 = int(i * cell_h), int((i + 1) * cell_h)
    x1, x2 = int(j * cell_w), int((j + 1) * cell_w)

    # sanitizar límites por posibles redondeos
    y1 = max(0, min(y1, h - 1))
    y2 = max(y1 + 1, min(y2, h))
    x1 = max(0, min(x1, w - 1))
    x2 = max(x1 + 1, min(x2, w))

    cell = img[y1:y2, x1:x2]
    if cell.size == 0:
        print(f"[WARN] Celda vacía {img_path} r{i+1} c{j+1}, salto.")
        continue

    base = os.path.basename(folder_path)
    name_no_ext, ext = os.path.splitext(fname)
    out_name = f"{base}_{name_no_ext}_r{i+1}c{j+1}_{uuid.uuid4().hex}{ext}"
    out_path = os.path.join(UNCROSSED_DIR, out_name)

    ok = cv2.imwrite(out_path, cv2.cvtColor(cell, cv2.COLOR_RGB2BGR))
    if ok:
        saved += 1
        if saved % 50 == 0:
            print(f"→ guardados {saved}/{TARGET_SAMPLES}")
    else:
        print(f"[WARN] Falló al guardar {out_path}")

print(f"Listo. Guardados {saved} recuadros en {UNCROSSED_DIR}.")
# Out:
# → guardados 50/4000
# → guardados 100/4000
# → guardados 150/4000
# → guardados 200/4000
# → guardados 250/4000
# → guardados 300/4000
# → guardados 350/4000
# → guardados 400/4000
# → guardados 450/4000
# → guardados 500/4000
# → guardados 550/4000
# → guardados 600/4000
# → guardados 650/4000
# → guardados 700/4000
# → guardados 750/4000
# → guardados 800/4000
# → guardados 850/4000
# → guardados 900/4000
# → guardados 950/4000
# → guardados 1000/4000
# → guardados 1050/4000
# → guardados 1100/4000
# → guardados 1150/4000
# → guardados 1200/4000
# → guardados 1250/4000
# → guardados 1300/4000
# → guardados 1350/4000
# → guardados 1400/4000
# → guardados 1450/4000
# → guardados 1500/4000
# → guardados 1550/4000
# → guardados 1600/4000
# → guardados 1650/4000
# → guardados 1700/4000
# → guardados 1750/4000
# → guardados 1800/4000
# → guardados 1850/4000
# → guardados 1900/4000
# → guardados 1950/4000
# → guardados 2000/4000
# → guardados 2050/4000
# → guardados 2100/4000
# → guardados 2150/4000
# → guardados 2200/4000
# → guardados 2250/4000
# → guardados 2300/4000
# → guardados 2350/4000
# → guardados 2400/4000
# → guardados 2450/4000
# → guardados 2500/4000
# → guardados 2550/4000
# → guardados 2600/4000
# → guardados 2650/4000
# → guardados 2700/4000
# → guardados 2750/4000
# → guardados 2800/4000
# → guardados 2850/4000
# → guardados 2900/4000
# → guardados 2950/4000
# → guardados 3000/4000
# → guardados 3050/4000
# → guardados 3100/4000
# → guardados 3150/4000
# → guardados 3200/4000
# → guardados 3250/4000
# → guardados 3300/4000
# → guardados 3350/4000
# → guardados 3400/4000
# → guardados 3450/4000
# → guardados 3500/4000
# → guardados 3550/4000
# → guardados 3600/4000
# → guardados 3650/4000
# → guardados 3700/4000
# → guardados 3750/4000
# → guardados 3800/4000
# → guardados 3850/4000
# → guardados 3900/4000
# → guardados 3950/4000
# → guardados 4000/4000
# Listo. Guardados 4000 recuadros en cropped_columns/1-UNCROSSED.

# %% [markdown]
# ### Seleccion de X o noX manual

# %%
# configuro paths
CROPS_DIR     = "cropped_columns"
CROSSED_DIR   = "cropped_columns/0-CROSSED"
UNCROSSED_DIR = "cropped_columns/0-UNCROSSED"

os.makedirs(CROSSED_DIR, exist_ok=True)
os.makedirs(UNCROSSED_DIR, exist_ok=True)

# especificaciones de grilla (n_filas, n_columnas)
grid_specs = {
    "col1": (14, 4),
    "col2": (14, 4),
    "cpl3": (12, 4),
}

# recolecto todas las imagenes de grillas válidas
candidates = []
for folder in os.listdir(CROPS_DIR):
    fp = os.path.join(CROPS_DIR, folder)
    if not os.path.isdir(fp): continue
    for fname in os.listdir(fp):
        cls, ext = os.path.splitext(fname)
        if cls in grid_specs:
            candidates.append((fp, fname, grid_specs[cls]))

if not candidates:
    raise RuntimeError("No grid images found in your crops directory!")

# annotation loop
while True:
    # pick random image + spec
    folder_path, fname, (n_rows, n_cols) = random.choice(candidates)
    img_path = os.path.join(folder_path, fname)

    # load & compute cell dims
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w, _ = img.shape
    cell_h, cell_w = h / n_rows, w / n_cols

    # pick random cell
    i = random.randrange(n_rows)
    j = random.randrange(n_cols)
    y1, y2 = int(i*cell_h), int((i+1)*cell_h)
    x1, x2 = int(j*cell_w), int((j+1)*cell_w)
    cell = img[y1:y2, x1:x2]

    # show popup
    cv2.namedWindow("ANNOTATOR — x=yes, n=no, q=quit", cv2.WINDOW_NORMAL)
    cv2.imshow("ANNOTATOR — x=yes, n=no, q=quit", cv2.cvtColor(cell, cv2.COLOR_RGB2BGR))
    key = cv2.waitKey(0) & 0xFF
    cv2.destroyAllWindows()

    # handle response
    if key == ord('q'):
        print("Quitting annotation.")
        break
    elif key == ord('x'):
        dest = CROSSED_DIR
    elif key == ord('n'):
        dest = UNCROSSED_DIR
    else:
        print("Unrecognized key, skipping this cell.")
        continue

    # build unique filename and save
    base = os.path.basename(folder_path)
    name_no_ext, ext = os.path.splitext(fname)
    out_name = f"{base}_{name_no_ext}_r{i+1}c{j+1}_{uuid.uuid4().hex}{ext}"
    out_path = os.path.join(dest, out_name)
    cv2.imwrite(out_path, cv2.cvtColor(cell, cv2.COLOR_RGB2BGR))
    print(f"→ saved to {out_path}")
# Out:
# → saved to cropped_columns/0-CROSSED/sample337_col2_r3c3_a2d7673f5b3042adba6e2efd69086fe1.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r4c3_c2b1070e4d4e4a65b3b944da75df0eb1.png
# → saved to cropped_columns/0-CROSSED/sample337_col2_r11c2_4a602eafbcfa4498b16d98961614b232.png
# → saved to cropped_columns/0-CROSSED/sample337_col2_r3c3_c3af26f3cc294774a28b0176eeb32a45.png
# → saved to cropped_columns/0-CROSSED/sample338_col1_r5c1_fca68fce0dfc4cd399f9a3bf72c0b6b5.png
# → saved to cropped_columns/0-CROSSED/sample337_col2_r7c3_05c6109c0b8b47ef9dbfad0f8553f30f.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r2c3_9bbe84b0e3554c5d86d3158b8f912174.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r2c3_6b45efab1a394819a8b8011fa93314bf.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r12c1_123d01365ff44eb98a31ed167843a203.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r2c4_e27da28e674c41d38ffaad19224e7e93.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r12c3_d77a6aec02eb4f77a2342170036af8d3.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r12c2_bfc380f35f364c57873ba5d36684157e.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r14c2_8c22a497b46643e28e69b8d67363fccc.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c3_8aa7bfa88ae0428994a497eacfd7a9b7.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r12c3_aa90b197c69f40a5941761ca33c55f67.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r1c2_7d8f4f5858a746288ff99d46032e6915.png
# → saved to cropped_columns/0-CROSSED/sample337_col2_r13c3_06318faa06514e88a6728e651d0502a2.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r12c1_3c391a6d891c4512964ebc0e6b2818bc.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r9c4_f6ac4d47e5da47daaf44a9dbda21959f.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r5c2_e14042bc25ec48df89de2c680fd1fda5.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r11c3_c780da63ff5045e9b8105a906cd1a0a6.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r12c1_55815e7f21c7478e8b3aa500581337f2.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r6c3_5cca0e63433b41269b00ea73be2fb432.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r4c3_3f59922c2e5e48f59708f86e26e66b49.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r4c1_bd5661bcf9ab477f809b1384f49daa77.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r9c1_2825b3cf450a47438e4a2cc8ee9f3c47.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r7c3_2396164fb0f848d2b424b5a57ced8b31.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r10c4_a54649ff115f4aa6b90d6b960c4f94ca.png
# → saved to cropped_columns/0-CROSSED/sample337_col1_r5c3_dc39d84a67a640779865634b06ab431a.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r5c2_abef82cb868c4d31b9c456eb00918570.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r14c2_c482ab3c1e3f4c9daa70a786173aed95.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r6c3_d3a585ca54344bb4a2fe044c647d495c.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r11c1_156506dd01b743558d7cb88ad658d511.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r2c2_5db2c4c101734b51b115f3b9ead91e7e.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c2_e1344b140d0643d9ae3fa4644ffeed12.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r3c2_40fe07e498b34ba286b67b0a77791783.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r1c2_95f51fd4e22d4c9b9f3da2368af27fb0.png
# → saved to cropped_columns/0-CROSSED/sample337_col1_r11c3_5ccd2eca73c3428fb39329636aebadd3.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r1c3_88bd762eaf8d46ac880744b4f1740cd0.png
# → saved to cropped_columns/0-CROSSED/sample337_col1_r4c2_c71e6c428c7640749b127d873b695bcc.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r7c1_f8a8360fecaf4feea4fbac670862cb9d.png
# → saved to cropped_columns/0-CROSSED/sample337_col1_r4c2_26ca4eed23d24fe0906a4d5040aa196c.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r4c4_66e35b48d68b465b96155751e659b547.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r13c1_0265ee35d7904207a05e0e89ad2525c7.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r10c4_94f2e8416dc74a39964fb674346aa664.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r6c2_28374388b6c644c5a4f993846fd0a9ca.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r5c3_850e9f055c1b4660beb47ca027ff15fa.png
# → saved to cropped_columns/0-CROSSED/sample338_col1_r10c1_57a647306a13499189bd79b68721f06d.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r12c2_b8e2c6195bf14d1991f27a7c7f58857f.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r7c2_57cb39cad1134a72867c63c080c5e567.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r11c4_ceb6500a50d7434f93a7ecefc8738819.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r13c1_6902a73e7bf5431da141387909d2c5ef.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r2c4_3aacd4071fd14538bca7b6f8d98bb678.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r8c2_607c1a7ee76f4881b40c2a3ee4a81407.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r4c4_c847ec0dedc648ba981634927e0b0a4b.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r7c1_54dba232967b4284ba20d04de1a17ee1.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r2c3_48b808d22f624ce282d53a5a03e6284c.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r9c4_b4405fb17bfe491099e90c8234a599ef.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r10c3_bfed2e1d7a30464c8797b0849fbae52c.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r9c1_602f3c282d374fb8a291b8ba4d720ed8.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r14c2_9088d3a71c114b0eb30e02178c1f2c3a.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r2c1_e9c30def325c4c84a2e8034d248da7b1.png
# → saved to cropped_columns/0-CROSSED/sample337_col2_r3c3_dde64255f51949f6b7d01bc092275018.png
# → saved to cropped_columns/0-CROSSED/sample338_col1_r7c4_f53c749a357644d4956428cec04a961b.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r14c1_e8ca2a4d749c4817bb7bea01c5b130f1.png
# → saved to cropped_columns/0-CROSSED/sample337_col2_r10c3_1fefdc6c74c340b9af1783212c82774a.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r13c4_bba5e9daceb54495ab908e5b4434b8f4.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r10c4_a0f4df8cfecc4318a920c990542fcf09.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r12c2_30af6bc1abb94311ab6bfcf3bfb3d1b4.png
# → saved to cropped_columns/0-CROSSED/sample338_col2_r8c3_414d3657237e40e0a03ca8a3a381be71.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r8c4_9d3f58e5cf7e429b86285665f8796600.png
# → saved to cropped_columns/0-CROSSED/sample338_col1_r1c2_34591a7f07b54dc7ab0ab715faf9c9cf.png
# → saved to cropped_columns/0-CROSSED/sample338_col1_r11c4_07411051a75b4c93bbab933b2c29cb88.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r2c4_285083d366ef43ad89dcfe4529cc10d0.png
# → saved to cropped_columns/0-CROSSED/sample337_col2_r14c3_1a3e55ec2bd74110b4b460a1fb10f422.png
# → saved to cropped_columns/0-CROSSED/sample337_col1_r1c2_40828bd932294875a470f59d9fbd26c6.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r3c2_98b6a97b9a2e4169816303d70f3ed8de.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r10c3_a6473c4e72034647a7347bb0aa38a29f.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r13c4_db8fdaeab8d842e480b4d649d32638c4.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r6c3_7aec831168df423e8c82b888276350ab.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r14c1_723b65e13add4a54b7c90f07d1de69ab.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r7c2_524c735305424b5c99b3eb6e6b19188e.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r7c4_0693a03f729e4295b54b155f67249d84.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r5c3_ac587f588da540458a1f24d78412e685.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r8c3_bf879886923648dbac3082eb39adaa32.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r7c4_679c6d3196324933a11d0f075fe300bf.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r7c4_b84cd3037e5a4e039f35e59a7b22ca97.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r1c4_9d9285a1ce794e8098080c1334335fe6.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r5c4_ea76855aa4b344beadd0be3ecde386ce.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r6c2_89d5b3207ee94d8ea7aed87683e86af1.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r3c1_241db5b510ac4510b1362365fd162262.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r8c3_bd7d0e0ec3024998a53a3cbb1c6fef7f.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r1c3_93636f3e58c2446c95244bc4dbbbb617.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r8c1_047db1c72f564f5a84700856c7b2810e.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r5c2_59d611000f8342e5809b407de184e0d9.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r8c2_7f3ca935b8b44c51abe7a7ad3ef27b55.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r5c2_331e694dcd20404486cfc4132d9d814b.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r10c2_1c28eedd4d6e41cc9d632ebcaf5eeeb0.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r1c4_b5964a8603c84400b96be93303e391ee.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r14c4_52e4c4d12a5140b2982929e65785ea0e.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c4_1aeee34f1d6a49e593205a7031711a1b.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r7c4_36c56aaf5e964c60aee65054d004e4c0.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r6c3_1446e675c6bb4dfd837c72fe993612b1.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r10c2_8ecce9004828438f89e493c6ea4b774f.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r8c2_73f4c4de8ce147359e96844480e8bf89.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r14c3_a2d78103896a45e98be15152a57078f7.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c1_60de965890d146868f5b09fe5030e01b.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r1c4_2e7e7c329cdb4fc2be7060669882a285.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r7c3_f4193eb224804a5092aa582262d4d59c.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r6c3_2600726941054dfb94f9bb4bd219e7c9.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r11c4_af4ef71fa4ae410faabc0787bcbf7c78.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r12c1_e56bf528e4d94c70bab9b6e9d905963b.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r8c3_ac011a5f0a3e446aa5bda625bd19b25a.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r9c3_1e9293783f7e417fa855534639454d22.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r5c1_7b638cf29df549a4ad59956818492910.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r10c1_cab84f09ec244b2c9d4822ebbda03473.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r7c4_2833ddbedbb04414b502e7fc13d989a7.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r11c4_4dfec288964d459291b9ffed0b9f036e.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r10c1_7fd2f322789e43d4958fa420596c975b.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r9c3_8451b47daf9e41d59155ab2e5aa4584a.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r14c1_13ea2f0405d94d05ac9d8d38192defbd.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r13c3_2c4be787d79f4db8b2739dccf13799ac.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r2c3_7293741a63884395991707a4efd060da.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r9c4_c67bb2f5cdfd4052843309c2a398b527.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r5c3_10d7c2ebe05445b191396001a42b5095.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r2c4_e57bb4e911464959a08d876c0fb6399e.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r14c2_09e5789dc58e4eb7ab06e419f30f5ea5.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r5c1_cba713ab18c54564be2237eed35ea264.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r12c2_ab23fd52dd7c45a7a6ffec9da70665bb.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r4c1_75425b94627d46f28e98761159e5cdf7.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r8c1_9e4e0c5f8c194a6fb9fa6a17507eff86.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r5c4_f8be521538454e5997f8dce0ac61a37f.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r12c2_2c5d006e132442419e24e10faa496ba1.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r11c2_7ba15497ea004a7a911c286cca7a85fa.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r5c2_78bf65c252ea4cae8dca5e509df350e4.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r10c4_be6546e40e674044b7fd2d853f645a61.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r5c1_9553ba092c2a469698aac0ed62ab5fd9.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r2c3_8def54ffd991411884646bad1f917ca5.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r11c4_1ce9a6ef6a8d4c04b9435400bec39b7c.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c4_184a0ca03f7d480f8262645f3751e0d3.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r8c1_1630334dac164f7c8fa08396c1a36bab.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r5c4_e50248c5cb5e41f6be2717bd3a5b3bea.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r11c1_a243fd6654fd49f6b04f3e4a10c44667.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r1c4_6a1ed2232a6e466696b4d952cefdf67d.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c1_2e117c56a964490a8009636f237955d4.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r11c3_6ba827db5cc14503b17ceca53264b575.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r5c3_22a5b2e532f64ddeb9c8cf0c57563135.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r4c3_f2c9648e49714c698d04a915e7f1523b.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r1c2_cbb348801e8747019179f63ecf8d602f.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c1_13275eb829b44decb81371e38c7a8915.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r13c3_5ac84854450742aaae0b056679771b8f.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c4_333f2828320d45fda366ea199d116cb5.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r6c1_49b3937766ef4268b460ddca180db906.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r2c1_b18fd157436b439db6bb6b8ef00b718a.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r12c1_ed240998ad0b43cca2d143cd454f0ffc.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r7c4_61f99546d6674ebe85a29bf18c035986.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r12c1_00d43892f68e47e7ac1385f709b6ce8a.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r3c3_bc03a7c829f247c5ac2a4c2a37d16f53.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r10c2_7c2a13f676894d2eb8c2d207bd4acab3.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r5c4_8c2455aad4fd4a769c1cd8fd4b14db5b.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r9c3_4f0855d3bf464bba9d8b4e90444e86d4.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r2c1_3636d7f5f4d64f38bbebba0c46d762a2.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r1c3_0014856ef761458fb86e032282ac08ea.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r13c2_13426fb8bd8143248cf4b7f16740ccaf.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r2c2_de4317aa487f4253828e099759af95c5.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r14c4_6a970ce2e5494df4ac1a1e67df3fe701.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r2c1_9970b0e449fc4cd6821cb39972be0424.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c1_2ee21f70db0c435b8b4cfe75a2e9e732.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r1c2_eae57a6626e543b2b0a8c137eb832c34.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r2c2_44556e3b2c5a49e68155c69331023b07.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r4c1_2e5ebebbde0a477e937bedc5f575121a.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r9c4_88016620fbd944f78962f91a834bce26.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r11c1_09e8eca1137d433684124a422e513f6a.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r5c2_2ce3976549ac40e29c9eb83293cf414c.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r13c1_7a1a274d37384e55936f2bc410b9a513.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r3c1_068fae087e174a8fa8ba2241b5087d2f.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r11c4_8cd40553ada74e2888ee0328277aaf59.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r11c2_e322d8f7f7ba47a5875eea918e48c3fa.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r1c2_82bd02c204b64e37bb73dd22e39da7e8.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r9c3_408df2de7850463cb2aad1f734f8320a.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r8c4_b94d1be835134182aa4f0fae10c61fb2.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r11c1_8bf69af317624b41b5e75ccba5272526.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r6c3_561c104347f643ab8cc3f2c8d1beb6a5.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r7c1_2b3566218f2b45a68fce96cc5dcd1cb5.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r9c1_080a044d3a904eb58edfd7279341ddaa.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r2c1_4375c8caf2864a57ba8654f0ea474de5.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r1c4_9fc0f9b5093447f4a3ec416a44371806.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r3c3_c40cd237a9154f19bf4849022bf93dde.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r13c2_b900e986d4434e9e937d930b7d0fa7e1.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r2c1_7e7b86cbc82a402aa49452476e82565a.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r6c4_7aead334b8244e54a20407247b967880.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r5c2_a5b10a72fd724207a1c03873b36e0197.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r3c4_9e530f81e93d43ec806a9b5eb633f600.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r10c2_3d2a84b14db34e64b21c973e4c31db6a.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r4c3_fc8362642ed34785a5209a72f767a508.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r1c3_5c95e5fce60e4a03a84ca3e09b037024.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r14c2_4f66428a5a19404aa5b47a1384157298.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r14c1_f3e34ddb3a034bb0865721e1fec6aba3.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r2c3_417d69c20bb34207b3c0b456e295d390.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r13c2_5031cafb68554f5fa01c4487b2c0bcab.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r9c4_2f40281e31694c559f47ff8145e94e42.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r7c4_699d6430007f4f039f4ee89d143c0965.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r11c3_eac3b4dea49f414d96efce0eda25c640.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r6c4_91c59d89dfdf4d9ab35b91fe965aeae2.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r4c4_0bb126498ff541c8b55a0bd8b9da77a7.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r14c2_f430cc2b818c4e849b79d8a7753714e0.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col2_r3c1_dab4ef40f33a4449b450648872f43882.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r8c4_e1731cc08e2e45fca1e57d1cff613a99.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r13c2_90c0f21323a6450990d19463d2c592c4.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col1_r11c1_b811af898ab44d409efae2dbf33fd7e2.png
# → saved to cropped_columns/0-UNCROSSED/sample337_col1_r6c3_b2046b0330514051a50a8d3a1441076e.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r7c1_cb08aad6fd824950891c361fbf229b1d.png
# → saved to cropped_columns/0-UNCROSSED/sample338_col2_r10c1_1f8dcc5f02ef429ab8b0a9aee582dde3.png
# Quitting annotation.
